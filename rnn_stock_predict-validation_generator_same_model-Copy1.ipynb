# %%
# %config IPCompleter.greedy=True

# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# train = pd.read_csv('Google_Stock_Price_Train.csv')
# train

# %%
train = pd.read_csv('Google_Stock_Price_Train.csv',index_col='Date',parse_dates=True) #CHANGE from /Data -> /DATA
train #1258 rows
# Out:
#               Open    High     Low   Close      Volume
# Date
# 2012-01-03  325.25  332.83  324.97  663.59   7,380,500
# 2012-01-04  331.27  333.87  329.08  666.45   5,749,400
# 2012-01-05  329.83  330.75  326.89  657.21   6,590,300
# 2012-01-06  328.34  328.77  323.68  648.24   5,405,900
# 2012-01-09  322.04  322.29  309.46  620.76  11,688,800
# ...            ...     ...     ...     ...         ...
# 2016-12-23  790.90  792.74  787.28  789.91     623,400
# 2016-12-27  790.68  797.86  787.66  791.55     789,100
# 2016-12-28  793.70  794.23  783.20  785.05   1,153,800
# 2016-12-29  783.33  785.93  778.92  782.79     744,300
# 2016-12-30  782.75  782.78  770.41  771.82   1,770,000
#
# [1258 rows x 5 columns]

# %%
train.rename(columns ={'Open':'Price'}, inplace=True)
train
# Out:
#              Price    High     Low   Close      Volume
# Date
# 2012-01-03  325.25  332.83  324.97  663.59   7,380,500
# 2012-01-04  331.27  333.87  329.08  666.45   5,749,400
# 2012-01-05  329.83  330.75  326.89  657.21   6,590,300
# 2012-01-06  328.34  328.77  323.68  648.24   5,405,900
# 2012-01-09  322.04  322.29  309.46  620.76  11,688,800
# ...            ...     ...     ...     ...         ...
# 2016-12-23  790.90  792.74  787.28  789.91     623,400
# 2016-12-27  790.68  797.86  787.66  791.55     789,100
# 2016-12-28  793.70  794.23  783.20  785.05   1,153,800
# 2016-12-29  783.33  785.93  778.92  782.79     744,300
# 2016-12-30  782.75  782.78  770.41  771.82   1,770,000
#
# [1258 rows x 5 columns]

# %%
train1 = train['Price']
train1
# Out:
# Date
# 2012-01-03    325.25
# 2012-01-04    331.27
# 2012-01-05    329.83
# 2012-01-06    328.34
# 2012-01-09    322.04
#                ...
# 2016-12-23    790.90
# 2016-12-27    790.68
# 2016-12-28    793.70
# 2016-12-29    783.33
# 2016-12-30    782.75
# Name: Price, Length: 1258, dtype: float64

# %%
train = train[['Price']]
train #1258
# Out:
#              Price
# Date
# 2012-01-03  325.25
# 2012-01-04  331.27
# 2012-01-05  329.83
# 2012-01-06  328.34
# 2012-01-09  322.04
# ...            ...
# 2016-12-23  790.90
# 2016-12-27  790.68
# 2016-12-28  793.70
# 2016-12-29  783.33
# 2016-12-30  782.75
#
# [1258 rows x 1 columns]

# %%
train.plot(figsize = (12,8))

# %% [markdown]
# ### Train Test Split -> already splited csv file

# %%
#test1 = pd.read_csv('Google_Stock_Price_Test.csv')
# test1

# %%
test = pd.read_csv('Google_Stock_Price_Test.csv', index_col='Date', parse_dates = True) 
test
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2017-01-03  778.81  789.63  775.80  786.14  1,657,300
# 2017-01-04  788.36  791.34  783.16  786.90  1,073,000
# 2017-01-05  786.08  794.48  785.02  794.02  1,335,200
# 2017-01-06  795.26  807.90  792.20  806.15  1,640,200
# 2017-01-09  806.40  809.97  802.83  806.65  1,272,400
# 2017-01-10  807.86  809.13  803.51  804.79  1,176,800
# 2017-01-11  805.00  808.15  801.37  807.91  1,065,900
# 2017-01-12  807.14  807.39  799.17  806.36  1,353,100
# 2017-01-13  807.48  811.22  806.69  807.88  1,099,200
# 2017-01-17  807.08  807.14  800.37  804.61  1,362,100
# 2017-01-18  805.81  806.21  800.99  806.07  1,294,400
# 2017-01-19  805.12  809.48  801.80  802.17    919,300
# 2017-01-20  806.91  806.91  801.69  805.02  1,670,000
# 2017-01-23  807.25  820.87  803.74  819.31  1,963,600
# 2017-01-24  822.30  825.90  817.82  823.87  1,474,000
# 2017-01-25  829.62  835.77  825.06  835.67  1,494,500
# 2017-01-26  837.81  838.00  827.01  832.15  2,973,900
# 2017-01-27  834.71  841.95  820.44  823.31  2,965,800
# 2017-01-30  814.66  815.84  799.80  802.32  3,246,600
# 2017-01-31  796.86  801.25  790.52  796.79  2,160,600

# %%
test  = test.rename(columns={'Open':'Price'})
test #20 rows
# Out:
#              Price    High     Low   Close     Volume
# Date
# 2017-01-03  778.81  789.63  775.80  786.14  1,657,300
# 2017-01-04  788.36  791.34  783.16  786.90  1,073,000
# 2017-01-05  786.08  794.48  785.02  794.02  1,335,200
# 2017-01-06  795.26  807.90  792.20  806.15  1,640,200
# 2017-01-09  806.40  809.97  802.83  806.65  1,272,400
# 2017-01-10  807.86  809.13  803.51  804.79  1,176,800
# 2017-01-11  805.00  808.15  801.37  807.91  1,065,900
# 2017-01-12  807.14  807.39  799.17  806.36  1,353,100
# 2017-01-13  807.48  811.22  806.69  807.88  1,099,200
# 2017-01-17  807.08  807.14  800.37  804.61  1,362,100
# 2017-01-18  805.81  806.21  800.99  806.07  1,294,400
# 2017-01-19  805.12  809.48  801.80  802.17    919,300
# 2017-01-20  806.91  806.91  801.69  805.02  1,670,000
# 2017-01-23  807.25  820.87  803.74  819.31  1,963,600
# 2017-01-24  822.30  825.90  817.82  823.87  1,474,000
# 2017-01-25  829.62  835.77  825.06  835.67  1,494,500
# 2017-01-26  837.81  838.00  827.01  832.15  2,973,900
# 2017-01-27  834.71  841.95  820.44  823.31  2,965,800
# 2017-01-30  814.66  815.84  799.80  802.32  3,246,600
# 2017-01-31  796.86  801.25  790.52  796.79  2,160,600

# %%
test = test[['Price']]
test #20
# Out:
#              Price
# Date
# 2017-01-03  778.81
# 2017-01-04  788.36
# 2017-01-05  786.08
# 2017-01-06  795.26
# 2017-01-09  806.40
# 2017-01-10  807.86
# 2017-01-11  805.00
# 2017-01-12  807.14
# 2017-01-13  807.48
# 2017-01-17  807.08
# 2017-01-18  805.81
# 2017-01-19  805.12
# 2017-01-20  806.91
# 2017-01-23  807.25
# 2017-01-24  822.30
# 2017-01-25  829.62
# 2017-01-26  837.81
# 2017-01-27  834.71
# 2017-01-30  814.66
# 2017-01-31  796.86

# %%
df = pd.concat((train, test), axis=0) # 1258 + 20 = 1278
df #1278
# Out:
#              Price
# Date
# 2012-01-03  325.25
# 2012-01-04  331.27
# 2012-01-05  329.83
# 2012-01-06  328.34
# 2012-01-09  322.04
# ...            ...
# 2017-01-25  829.62
# 2017-01-26  837.81
# 2017-01-27  834.71
# 2017-01-30  814.66
# 2017-01-31  796.86
#
# [1278 rows x 1 columns]

# %% [markdown]
# ## From this time on, We use train_split, test_split instead of trian, test !!
# ### split train test again from concated dataframe : test size for 120 since length is 60, test size >= length

# %%
len(df)
# Out:
# 1278

# %% [markdown]
# ##### Data is daily, let's forcast   4 months(0.1 * 1278 , about 120 days) into the future(test_size is 120 days)

# %%
len(df)- 120
# Out:
# 1158

# %%
test_size  = 120

# %%
test_ind = len(df) - test_size
test_ind
# Out:
# 1158

# %%
train_split = df.iloc[:test_ind]
print(train_split.shape)
train_split
# Out:
# (1158, 1)
#              Price
# Date
# 2012-01-03  325.25
# 2012-01-04  331.27
# 2012-01-05  329.83
# 2012-01-06  328.34
# 2012-01-09  322.04
# ...            ...
# 2016-08-03  767.18
# 2016-08-04  772.22
# 2016-08-05  773.78
# 2016-08-08  782.00
# 2016-08-09  781.10
#
# [1158 rows x 1 columns]

# %%
test_split = df.iloc[test_ind:]
print(test_split.shape)
test_split
# Out:
# (120, 1)
#              Price
# Date
# 2016-08-10  783.75
# 2016-08-11  785.00
# 2016-08-12  781.50
# 2016-08-15  783.75
# 2016-08-16  780.30
# ...            ...
# 2017-01-25  829.62
# 2017-01-26  837.81
# 2017-01-27  834.71
# 2017-01-30  814.66
# 2017-01-31  796.86
#
# [120 rows x 1 columns]

# %% [markdown]
# ### Scale Data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
scaled_train = scaler.transform(train_split)
print(scaled_train.shape)
scaled_train #size 1198
# Out:
# (1158, 1)
# array([[0.08581368],
#        [0.09701243],
#        [0.09433366],
#        ...,
#        [0.92019495],
#        [0.93548627],
#        [0.93381204]])

# %%
scaled_test = scaler.transform(test_split)
print(scaled_test.shape)
scaled_test  #size 80
# Out:
# (120, 1)
# array([[0.93874172],
#        [0.94106704],
#        [0.93455614],
#        [0.93874172],
#        [0.93232383],
#        [0.92678027],
#        [0.93178436],
#        [0.92246447],
#        [0.91924622],
#        [0.92335739],
#        [0.91424213],
#        [0.90758241],
#        [0.91130292],
#        [0.91081926],
#        [0.91191681],
#        [0.90760101],
#        [0.91176799],
#        [0.91876256],
#        [0.91958107],
#        [0.93176576],
#        [0.92914279],
#        [0.91334921],
#        [0.88550115],
#        [0.90289456],
#        [0.89383511],
#        [0.89993675],
#        [0.91269812],
#        [0.917665  ],
#        [0.91130292],
#        [0.91811147],
#        [0.93176576],
#        [0.94402485],
#        [0.93686286],
#        [0.9233946 ],
#        [0.9277662 ],
#        [0.93444453],
#        [0.92493861],
#        [0.92106928],
#        [0.92438053],
#        [0.93048218],
#        [0.9299055 ],
#        [0.93113327],
#        [0.92750577],
#        [0.94415507],
#        [0.93876032],
#        [0.93403527],
#        [0.93483518],
#        [0.9313937 ],
#        [0.94636878],
#        [0.96569685],
#        [0.97510976],
#        [0.95966962],
#        [0.97808617],
#        [1.        ],
#        [0.98076494],
#        [0.97083116],
#        [0.98450406],
#        [0.96054394],
#        [0.9371419 ],
#        [0.92841729],
#        [0.90804747],
#        [0.8771858 ],
#        [0.92153434],
#        [0.93809063],
#        [0.93165414],
#        [0.95254483],
#        [0.88812412],
#        [0.88637547],
#        [0.87032145],
#        [0.88563137],
#        [0.90743359],
#        [0.91571173],
#        [0.89941588],
#        [0.91805566],
#        [0.9089404 ],
#        [0.9024853 ],
#        [0.89456061],
#        [0.91600938],
#        [0.9132934 ],
#        [0.88979835],
#        [0.86589404],
#        [0.89030062],
#        [0.90335962],
#        [0.89642086],
#        [0.91777662],
#        [0.93176576],
#        [0.94114145],
#        [0.95762334],
#        [0.96413424],
#        [0.96402262],
#        [0.96971501],
#        [0.95077759],
#        [0.96294367],
#        [0.96123223],
#        [0.95475854],
#        [0.95204256],
#        [0.95163331],
#        [0.95725128],
#        [0.93796041],
#        [0.93688146],
#        [0.92955205],
#        [0.94731751],
#        [0.94307612],
#        [0.96015329],
#        [0.98087655],
#        [0.98359253],
#        [0.97827219],
#        [0.98225314],
#        [0.98288563],
#        [0.98214153],
#        [0.979779  ],
#        [0.97849542],
#        [0.98182528],
#        [0.98245777],
#        [1.01045465],
#        [1.02407173],
#        [1.03930724],
#        [1.03354044],
#        [0.99624228],
#        [0.9631297 ]])

# %% [markdown]
# ## Time Series Generator

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %% [markdown]
# #### Create generator from scaled_train dataset.

# %%
# Let's redefine to get 60 days back and then predict the next day open stock price.
length = 60
generator = TimeseriesGenerator(scaled_train, scaled_train, length=length, batch_size=1)

# %%
print("len(generator) : ",len(generator)) #1138 generator, each generator has array with 60 elements.
print(type(generator))
# Out:
# len(generator) :  1098
# <class 'tensorflow.python.keras.preprocessing.sequence.TimeseriesGenerator'>

# %%
# What does the first batch look like?
X,y = generator[0]

# %%
print(X)
print(f'Given the Array: \n{X.flatten()}') #60
print(f'Predict this y: \n {y}') # 1
# Out:
# [[[0.08581368]
#   [0.09701243]
#   [0.09433366]
#   [0.09156187]
#   [0.07984225]
#   [0.0643277 ]
#   [0.0585423 ]
#   [0.06568569]
#   [0.06109085]
#   [0.06639259]
#   [0.0614257 ]
#   [0.07474514]
#   [0.02797827]
#   [0.02379269]
#   [0.02409033]
#   [0.0159238 ]
#   [0.01078949]
#   [0.00967334]
#   [0.01642607]
#   [0.02100231]
#   [0.02280676]
#   [0.02273235]
#   [0.02810849]
#   [0.03212665]
#   [0.0433812 ]
#   [0.04475779]
#   [0.04790163]
#   [0.0440695 ]
#   [0.04648783]
#   [0.04745517]
#   [0.04873875]
#   [0.03936305]
#   [0.04137213]
#   [0.04034898]
#   [0.04784582]
#   [0.04325099]
#   [0.04356723]
#   [0.04286033]
#   [0.04602277]
#   [0.05398467]
#   [0.05738894]
#   [0.05714711]
#   [0.05569611]
#   [0.04421832]
#   [0.04514845]
#   [0.04605997]
#   [0.04412531]
#   [0.03675869]
#   [0.04486941]
#   [0.05065481]
#   [0.05214302]
#   [0.05612397]
#   [0.05818885]
#   [0.06540665]
#   [0.06882953]
#   [0.07243843]
#   [0.07993526]
#   [0.07846566]
#   [0.08034452]
#   [0.08497656]]]
# Given the Array:
# [0.08581368 0.09701243 0.09433366 0.09156187 0.07984225 0.0643277
#  0.0585423  0.06568569 0.06109085 0.06639259 0.0614257  0.07474514
#  0.02797827 0.02379269 0.02409033 0.0159238  0.01078949 0.00967334
#  0.01642607 0.02100231 0.02280676 0.02273235 0.02810849 0.03212665
#  0.0433812  0.04475779 0.04790163 0.0440695  0.04648783 0.04745517
#  0.04873875 0.03936305 0.04137213 0.04034898 0.04784582 0.04325099
#  0.04356723 0.04286033 0.04602277 0.05398467 0.05738894 0.05714711
#  0.05569611 0.04421832 0.04514845 0.04605997 0.04412531 0.03675869
#  0.04486941 0.05065481 0.05214302 0.05612397 0.05818885 0.06540665
#  0.06882953 0.07243843 0.07993526 0.07846566 0.08034452 0.08497656]
# Predict this y:
#  [[0.08627874]]

# %% [markdown]
# ### Create the Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
# We're only using one feature in our time series , column name : Price
n_features = 1

# %%
# define model
model = Sequential()
#large neuron for LSTM such as 100
model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))#100 output dimension,
model.add(Dense(1)) # one predictable output
model.compile(optimizer='adam', loss='mse') #contious variable.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               40800
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 40,901
# Trainable params: 40,901
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### EarlyStopping and creating a Validation Generator
#
# NOTE: The scaled_test dataset size MUST be greater than your length chosen for your batches. Review video for more info on this.

# %%
len(scaled_test)
# Out:
# 120

# %%
print("your length chosen for your batches : ",length)
# Out:
# your length chosen for your batches :  60

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
# early_stop = EarlyStopping(monitor='val_loss',patience=3) 
early_stop = EarlyStopping(monitor='val_loss',patience=1)

# %% [markdown]
# #### Create validation_generator from scaled_test dataset.

# %%
#produce batches for training/validation.(return A Sequence instance.)
validation_generator = TimeseriesGenerator(scaled_test,scaled_test, length=length, batch_size=1)

# %%
len(validation_generator) #create 20 batches : len(scaled_test): 80, length=60-> 80-60 =20, 20/1(batch_size)=> 20
# Out:
# 60

# %%
#check validation_generator's first elemnt out of 60
X_vg, y_vg = validation_generator[0]
print(X_vg.shape)
print(f"X_vg[0] length : {len(X_vg[0])} \n X_vg : \n { X_vg}")
print("y_vg : \n", y_vg)
# Out:
# (1, 60, 1)
# X_vg[0] length : 60
#  X_vg :
#  [[[0.93874172]
#   [0.94106704]
#   [0.93455614]
#   [0.93874172]
#   [0.93232383]
#   [0.92678027]
#   [0.93178436]
#   [0.92246447]
#   [0.91924622]
#   [0.92335739]
#   [0.91424213]
#   [0.90758241]
#   [0.91130292]
#   [0.91081926]
#   [0.91191681]
#   [0.90760101]
#   [0.91176799]
#   [0.91876256]
#   [0.91958107]
#   [0.93176576]
#   [0.92914279]
#   [0.91334921]
#   [0.88550115]
#   [0.90289456]
#   [0.89383511]
#   [0.89993675]
#   [0.91269812]
#   [0.917665  ]
#   [0.91130292]
#   [0.91811147]
#   [0.93176576]
#   [0.94402485]
#   [0.93686286]
#   [0.9233946 ]
#   [0.9277662 ]
#   [0.93444453]
#   [0.92493861]
#   [0.92106928]
#   [0.92438053]
#   [0.93048218]
#   [0.9299055 ]
#   [0.93113327]
#   [0.92750577]
#   [0.94415507]
#   [0.93876032]
#   [0.93403527]
#   [0.93483518]
#   [0.9313937 ]
#   [0.94636878]
#   [0.96569685]
#   [0.97510976]
#   [0.95966962]
#   [0.97808617]
#   [1.        ]
#   [0.98076494]
#   [0.97083116]
#   [0.98450406]
#   [0.96054394]
#   [0.9371419 ]
#   [0.92841729]]]
# y_vg :
#  [[0.90804747]]

# %% [markdown]
# [How to use Keras TimeseriesGenerator for time series data](https://www.dlology.com/blog/how-to-use-keras-timeseriesgenerator-for-time-series-data/)

# %% [markdown]
# #### fit_generator model with generator(X,y) and validation_generator(X,y)

# %%
# fit model by model.fit_generator(generator, validation_generator=validation_generator)
model.fit_generator(generator,epochs=100,
                    validation_data=validation_generator,
                   callbacks=[early_stop])
# Out:
# Epoch 1/100
# 1098/1098 [==============================] - 154s 140ms/step - loss: 0.0043 - val_loss: 9.0363e-04
# Epoch 2/100
# 1098/1098 [==============================] - 151s 137ms/step - loss: 0.0010 - val_loss: 0.0012

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()

# %% [markdown]
# ## Evaluate on Test Data

# %%
first_eval_batch = scaled_train[-length:]  # scaled_train[-60:]
# X_vg, y_vg = validation_generator[0] -> X_vg.shape -> (1,60,1)
print(first_eval_batch.shape) #(60, 1) -> need to be (1,60,1) for prediction 
n_input = length #60
# Out:
# (60, 1)

# %%
current_batch = first_eval_batch.reshape((1, n_input, n_features)) #(1,60,1) <- X.shape of generator[0] is (1,60,1)

# %%
print(current_batch.shape)
current_batch # scaled_train[-60:] , nd.array with 60 elements from scaled_train
# Out:
# (1, 60, 1)
# array([[[0.79992931],
#         [0.81269068],
#         [0.7897723 ],
#         [0.78733537],
#         [0.78595878],
#         [0.79509264],
#         [0.79570653],
#         [0.8215641 ],
#         [0.82548925],
#         [0.82760994],
#         [0.84198973],
#         [0.84717985],
#         [0.84340353],
#         [0.8373949 ],
#         [0.82928417],
#         [0.81985267],
#         [0.82751693],
#         [0.82548925],
#         [0.81916437],
#         [0.81365801],
#         [0.8136022 ],
#         [0.81829005],
#         [0.8106816 ],
#         [0.79903639],
#         [0.78065704],
#         [0.77996875],
#         [0.78119652],
#         [0.7782015 ],
#         [0.73675497],
#         [0.72899769],
#         [0.74382395],
#         [0.75132078],
#         [0.75591562],
#         [0.76843515],
#         [0.77561575],
#         [0.76430538],
#         [0.77937347],
#         [0.78201503],
#         [0.79792023],
#         [0.81851328],
#         [0.82688444],
#         [0.82308952],
#         [0.83080958],
#         [0.82519161],
#         [0.83854826],
#         [0.85238857],
#         [0.85802515],
#         [0.86081554],
#         [0.85860183],
#         [0.85556961],
#         [0.85415582],
#         [0.87045167],
#         [0.91820448],
#         [0.89658829],
#         [0.91072624],
#         [0.90791726],
#         [0.91729295],
#         [0.92019495],
#         [0.93548627],
#         [0.93381204]]])

# %%
#predict value based on X, training dataset. <- predict based on model trained with TimeseriesGenerator data instance
print(model.predict(current_batch).shape) #2-d
model.predict(current_batch)  #2-d
# Out:
# (1, 1)
# array([[0.8984247]], dtype=float32)

# %%
#actual y value.
scaled_test[0]
# Out:
# array([0.93874172])

# %%
print( model.predict(current_batch)[0].shape )#1-d no.array 
model.predict(current_batch)[0]
# Out:
# (1,)
# array([0.8984247], dtype=float32)

# %% [markdown]
# Now let's put this logic in a for loop to predict into the future for the entire test range.
#
# ----

# %% [markdown]
# **NOTE: PAY CLOSE ATTENTION HERE TO WHAT IS BEING OUTPUTED AND IN WHAT DIMENSIONS. ADD YOUR OWN PRINT() STATEMENTS TO SEE WHAT IS TRULY GOING ON!!**

# %%
len(test_split)
# Out:
# 120

# %%
test_predictions = []

first_eval_batch = scaled_train[-length:] 
current_batch = first_eval_batch.reshape((1, length, n_features))
print("* original current_batch :\n", current_batch) #60
print("==============================================================")

for i in range(len(test_split)): #80 
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    # model.predict(current_batch)[0], 1-d array(1,)[0.49245596] <-
    # <- model.predict(current_batch),2d (1,1)[[0.49245596]]
    current_pred = model.predict(current_batch)[0]
    print(f"*index {i}: current_pred : {model.predict(current_batch)[0]}")
    print('----------------------')
    # store prediction 
    test_predictions.append(current_pred) #list consist 18 np.array(1,)
    print(f"*test_predictions : \n",test_predictions)
    print("---------------------------------")
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1) #[[[0.49245596]]], 3-d(1,1,1)
    print("current_batch :\n", current_batch)
    print("****************************************")
# Out:
# * original current_batch :
#  [[[0.79992931]
#   [0.81269068]
#   [0.7897723 ]
#   [0.78733537]
#   [0.78595878]
#   [0.79509264]
#   [0.79570653]
#   [0.8215641 ]
#   [0.82548925]
#   [0.82760994]
#   [0.84198973]
#   [0.84717985]
#   [0.84340353]
#   [0.8373949 ]
#   [0.82928417]
#   [0.81985267]
#   [0.82751693]
#   [0.82548925]
#   [0.81916437]
#   [0.81365801]
#   [0.8136022 ]
#   [0.81829005]
#   [0.8106816 ]
#   [0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]]]
# ==============================================================
# *index 0: current_pred : [0.8984247]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.81269068]
#   [0.7897723 ]
#   [0.78733537]
#   [0.78595878]
#   [0.79509264]
#   [0.79570653]
#   [0.8215641 ]
#   [0.82548925]
#   [0.82760994]
#   [0.84198973]
#   [0.84717985]
#   [0.84340353]
#   [0.8373949 ]
#   [0.82928417]
#   [0.81985267]
#   [0.82751693]
#   [0.82548925]
#   [0.81916437]
#   [0.81365801]
#   [0.8136022 ]
#   [0.81829005]
#   [0.8106816 ]
#   [0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]]]
# ****************************************
# *index 1: current_pred : [0.8946292]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.7897723 ]
#   [0.78733537]
#   [0.78595878]
#   [0.79509264]
#   [0.79570653]
#   [0.8215641 ]
#   [0.82548925]
#   [0.82760994]
#   [0.84198973]
#   [0.84717985]
#   [0.84340353]
#   [0.8373949 ]
#   [0.82928417]
#   [0.81985267]
#   [0.82751693]
#   [0.82548925]
#   [0.81916437]
#   [0.81365801]
#   [0.8136022 ]
#   [0.81829005]
#   [0.8106816 ]
#   [0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]]]
# ****************************************
# *index 2: current_pred : [0.8903866]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.78733537]
#   [0.78595878]
#   [0.79509264]
#   [0.79570653]
#   [0.8215641 ]
#   [0.82548925]
#   [0.82760994]
#   [0.84198973]
#   [0.84717985]
#   [0.84340353]
#   [0.8373949 ]
#   [0.82928417]
#   [0.81985267]
#   [0.82751693]
#   [0.82548925]
#   [0.81916437]
#   [0.81365801]
#   [0.8136022 ]
#   [0.81829005]
#   [0.8106816 ]
#   [0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]]]
# ****************************************
# *index 3: current_pred : [0.8854559]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.78595878]
#   [0.79509264]
#   [0.79570653]
#   [0.8215641 ]
#   [0.82548925]
#   [0.82760994]
#   [0.84198973]
#   [0.84717985]
#   [0.84340353]
#   [0.8373949 ]
#   [0.82928417]
#   [0.81985267]
#   [0.82751693]
#   [0.82548925]
#   [0.81916437]
#   [0.81365801]
#   [0.8136022 ]
#   [0.81829005]
#   [0.8106816 ]
#   [0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]]]
# ****************************************
# *index 4: current_pred : [0.88000697]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.79509264]
#   [0.79570653]
#   [0.8215641 ]
#   [0.82548925]
#   [0.82760994]
#   [0.84198973]
#   [0.84717985]
#   [0.84340353]
#   [0.8373949 ]
#   [0.82928417]
#   [0.81985267]
#   [0.82751693]
#   [0.82548925]
#   [0.81916437]
#   [0.81365801]
#   [0.8136022 ]
#   [0.81829005]
#   [0.8106816 ]
#   [0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]]]
# ****************************************
# *index 5: current_pred : [0.8741807]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.79570653]
#   [0.8215641 ]
#   [0.82548925]
#   [0.82760994]
#   [0.84198973]
#   [0.84717985]
#   [0.84340353]
#   [0.8373949 ]
#   [0.82928417]
#   [0.81985267]
#   [0.82751693]
#   [0.82548925]
#   [0.81916437]
#   [0.81365801]
#   [0.8136022 ]
#   [0.81829005]
#   [0.8106816 ]
#   [0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]]]
# ****************************************
# *index 6: current_pred : [0.8680815]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.8215641 ]
#   [0.82548925]
#   [0.82760994]
#   [0.84198973]
#   [0.84717985]
#   [0.84340353]
#   [0.8373949 ]
#   [0.82928417]
#   [0.81985267]
#   [0.82751693]
#   [0.82548925]
#   [0.81916437]
#   [0.81365801]
#   [0.8136022 ]
#   [0.81829005]
#   [0.8106816 ]
#   [0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]
#   [0.86808151]]]
# ****************************************
# *index 7: current_pred : [0.8617865]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.82548925]
#   [0.82760994]
#   [0.84198973]
#   [0.84717985]
#   [0.84340353]
#   [0.8373949 ]
#   [0.82928417]
#   [0.81985267]
#   [0.82751693]
#   [0.82548925]
#   [0.81916437]
#   [0.81365801]
#   [0.8136022 ]
#   [0.81829005]
#   [0.8106816 ]
#   [0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]
#   [0.86808151]
#   [0.86178648]]]
# ****************************************
# *index 8: current_pred : [0.85535294]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.82760994]
#   [0.84198973]
#   [0.84717985]
#   [0.84340353]
#   [0.8373949 ]
#   [0.82928417]
#   [0.81985267]
#   [0.82751693]
#   [0.82548925]
#   [0.81916437]
#   [0.81365801]
#   [0.8136022 ]
#   [0.81829005]
#   [0.8106816 ]
#   [0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]
#   [0.86808151]
#   [0.86178648]
#   [0.85535294]]]
# ****************************************
# *index 9: current_pred : [0.84882367]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32), array([0.84882367], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.84198973]
#   [0.84717985]
#   [0.84340353]
#   [0.8373949 ]
#   [0.82928417]
#   [0.81985267]
#   [0.82751693]
#   [0.82548925]
#   [0.81916437]
#   [0.81365801]
#   [0.8136022 ]
#   [0.81829005]
#   [0.8106816 ]
#   [0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]
#   [0.86808151]
#   [0.86178648]
#   [0.85535294]
#   [0.84882367]]]
# ****************************************
# *index 10: current_pred : [0.842231]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32), array([0.84882367], dtype=float32), array([0.842231], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.84717985]
#   [0.84340353]
#   [0.8373949 ]
#   [0.82928417]
#   [0.81985267]
#   [0.82751693]
#   [0.82548925]
#   [0.81916437]
#   [0.81365801]
#   [0.8136022 ]
#   [0.81829005]
#   [0.8106816 ]
#   [0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]
#   [0.86808151]
#   [0.86178648]
#   [0.85535294]
#   [0.84882367]
#   [0.84223098]]]
# ****************************************
# *index 11: current_pred : [0.83559954]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32), array([0.84882367], dtype=float32), array([0.842231], dtype=float32), array([0.83559954], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.84340353]
#   [0.8373949 ]
#   [0.82928417]
#   [0.81985267]
#   [0.82751693]
#   [0.82548925]
#   [0.81916437]
#   [0.81365801]
#   [0.8136022 ]
#   [0.81829005]
#   [0.8106816 ]
#   [0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]
#   [0.86808151]
#   [0.86178648]
#   [0.85535294]
#   [0.84882367]
#   [0.84223098]
#   [0.83559954]]]
# ****************************************
# *index 12: current_pred : [0.8289478]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32), array([0.84882367], dtype=float32), array([0.842231], dtype=float32), array([0.83559954], dtype=float32), array([0.8289478], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.8373949 ]
#   [0.82928417]
#   [0.81985267]
#   [0.82751693]
#   [0.82548925]
#   [0.81916437]
#   [0.81365801]
#   [0.8136022 ]
#   [0.81829005]
#   [0.8106816 ]
#   [0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]
#   [0.86808151]
#   [0.86178648]
#   [0.85535294]
#   [0.84882367]
#   [0.84223098]
#   [0.83559954]
#   [0.82894778]]]
# ****************************************
# *index 13: current_pred : [0.8222903]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32), array([0.84882367], dtype=float32), array([0.842231], dtype=float32), array([0.83559954], dtype=float32), array([0.8289478], dtype=float32), array([0.8222903], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.82928417]
#   [0.81985267]
#   [0.82751693]
#   [0.82548925]
#   [0.81916437]
#   [0.81365801]
#   [0.8136022 ]
#   [0.81829005]
#   [0.8106816 ]
#   [0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]
#   [0.86808151]
#   [0.86178648]
#   [0.85535294]
#   [0.84882367]
#   [0.84223098]
#   [0.83559954]
#   [0.82894778]
#   [0.8222903 ]]]
# ****************************************
# *index 14: current_pred : [0.81563807]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32), array([0.84882367], dtype=float32), array([0.842231], dtype=float32), array([0.83559954], dtype=float32), array([0.8289478], dtype=float32), array([0.8222903], dtype=float32), array([0.81563807], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.81985267]
#   [0.82751693]
#   [0.82548925]
#   [0.81916437]
#   [0.81365801]
#   [0.8136022 ]
#   [0.81829005]
#   [0.8106816 ]
#   [0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]
#   [0.86808151]
#   [0.86178648]
#   [0.85535294]
#   [0.84882367]
#   [0.84223098]
#   [0.83559954]
#   [0.82894778]
#   [0.8222903 ]
#   [0.81563807]]]
# ****************************************
# *index 15: current_pred : [0.80900025]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32), array([0.84882367], dtype=float32), array([0.842231], dtype=float32), array([0.83559954], dtype=float32), array([0.8289478], dtype=float32), array([0.8222903], dtype=float32), array([0.81563807], dtype=float32), array([0.80900025], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.82751693]
#   [0.82548925]
#   [0.81916437]
#   [0.81365801]
#   [0.8136022 ]
#   [0.81829005]
#   [0.8106816 ]
#   [0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]
#   [0.86808151]
#   [0.86178648]
#   [0.85535294]
#   [0.84882367]
#   [0.84223098]
#   [0.83559954]
#   [0.82894778]
#   [0.8222903 ]
#   [0.81563807]
#   [0.80900025]]]
# ****************************************
# *index 16: current_pred : [0.80238384]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32), array([0.84882367], dtype=float32), array([0.842231], dtype=float32), array([0.83559954], dtype=float32), array([0.8289478], dtype=float32), array([0.8222903], dtype=float32), array([0.81563807], dtype=float32), array([0.80900025], dtype=float32), array([0.80238384], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.82548925]
#   [0.81916437]
#   [0.81365801]
#   [0.8136022 ]
#   [0.81829005]
#   [0.8106816 ]
#   [0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]
#   [0.86808151]
#   [0.86178648]
#   [0.85535294]
#   [0.84882367]
#   [0.84223098]
#   [0.83559954]
#   [0.82894778]
#   [0.8222903 ]
#   [0.81563807]
#   [0.80900025]
#   [0.80238384]]]
# ****************************************
# *index 17: current_pred : [0.7957943]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32), array([0.84882367], dtype=float32), array([0.842231], dtype=float32), array([0.83559954], dtype=float32), array([0.8289478], dtype=float32), array([0.8222903], dtype=float32), array([0.81563807], dtype=float32), array([0.80900025], dtype=float32), array([0.80238384], dtype=float32), array([0.7957943], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.81916437]
#   [0.81365801]
#   [0.8136022 ]
#   [0.81829005]
#   [0.8106816 ]
#   [0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]
#   [0.86808151]
#   [0.86178648]
#   [0.85535294]
#   [0.84882367]
#   [0.84223098]
#   [0.83559954]
#   [0.82894778]
#   [0.8222903 ]
#   [0.81563807]
#   [0.80900025]
#   [0.80238384]
#   [0.79579431]]]
# ****************************************
# *index 18: current_pred : [0.78923655]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32), array([0.84882367], dtype=float32), array([0.842231], dtype=float32), array([0.83559954], dtype=float32), array([0.8289478], dtype=float32), array([0.8222903], dtype=float32), array([0.81563807], dtype=float32), array([0.80900025], dtype=float32), array([0.80238384], dtype=float32), array([0.7957943], dtype=float32), array([0.78923655], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.81365801]
#   [0.8136022 ]
#   [0.81829005]
#   [0.8106816 ]
#   [0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]
#   [0.86808151]
#   [0.86178648]
#   [0.85535294]
#   [0.84882367]
#   [0.84223098]
#   [0.83559954]
#   [0.82894778]
#   [0.8222903 ]
#   [0.81563807]
#   [0.80900025]
#   [0.80238384]
#   [0.79579431]
#   [0.78923655]]]
# ****************************************
# *index 19: current_pred : [0.78271437]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32), array([0.84882367], dtype=float32), array([0.842231], dtype=float32), array([0.83559954], dtype=float32), array([0.8289478], dtype=float32), array([0.8222903], dtype=float32), array([0.81563807], dtype=float32), array([0.80900025], dtype=float32), array([0.80238384], dtype=float32), array([0.7957943], dtype=float32), array([0.78923655], dtype=float32), array([0.78271437], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.8136022 ]
#   [0.81829005]
#   [0.8106816 ]
#   [0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]
#   [0.86808151]
#   [0.86178648]
#   [0.85535294]
#   [0.84882367]
#   [0.84223098]
#   [0.83559954]
#   [0.82894778]
#   [0.8222903 ]
#   [0.81563807]
#   [0.80900025]
#   [0.80238384]
#   [0.79579431]
#   [0.78923655]
#   [0.78271437]]]
# ****************************************
# *index 20: current_pred : [0.7762311]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32), array([0.84882367], dtype=float32), array([0.842231], dtype=float32), array([0.83559954], dtype=float32), array([0.8289478], dtype=float32), array([0.8222903], dtype=float32), array([0.81563807], dtype=float32), array([0.80900025], dtype=float32), array([0.80238384], dtype=float32), array([0.7957943], dtype=float32), array([0.78923655], dtype=float32), array([0.78271437], dtype=float32), array([0.7762311], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.81829005]
#   [0.8106816 ]
#   [0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]
#   [0.86808151]
#   [0.86178648]
#   [0.85535294]
#   [0.84882367]
#   [0.84223098]
#   [0.83559954]
#   [0.82894778]
#   [0.8222903 ]
#   [0.81563807]
#   [0.80900025]
#   [0.80238384]
#   [0.79579431]
#   [0.78923655]
#   [0.78271437]
#   [0.77623111]]]
# ****************************************
# *index 21: current_pred : [0.7697895]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32), array([0.84882367], dtype=float32), array([0.842231], dtype=float32), array([0.83559954], dtype=float32), array([0.8289478], dtype=float32), array([0.8222903], dtype=float32), array([0.81563807], dtype=float32), array([0.80900025], dtype=float32), array([0.80238384], dtype=float32), array([0.7957943], dtype=float32), array([0.78923655], dtype=float32), array([0.78271437], dtype=float32), array([0.7762311], dtype=float32), array([0.7697895], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.8106816 ]
#   [0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]
#   [0.86808151]
#   [0.86178648]
#   [0.85535294]
#   [0.84882367]
#   [0.84223098]
#   [0.83559954]
#   [0.82894778]
#   [0.8222903 ]
#   [0.81563807]
#   [0.80900025]
#   [0.80238384]
#   [0.79579431]
#   [0.78923655]
#   [0.78271437]
#   [0.77623111]
#   [0.76978952]]]
# ****************************************
# *index 22: current_pred : [0.76339227]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32), array([0.84882367], dtype=float32), array([0.842231], dtype=float32), array([0.83559954], dtype=float32), array([0.8289478], dtype=float32), array([0.8222903], dtype=float32), array([0.81563807], dtype=float32), array([0.80900025], dtype=float32), array([0.80238384], dtype=float32), array([0.7957943], dtype=float32), array([0.78923655], dtype=float32), array([0.78271437], dtype=float32), array([0.7762311], dtype=float32), array([0.7697895], dtype=float32), array([0.76339227], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.79903639]
#   [0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]
#   [0.86808151]
#   [0.86178648]
#   [0.85535294]
#   [0.84882367]
#   [0.84223098]
#   [0.83559954]
#   [0.82894778]
#   [0.8222903 ]
#   [0.81563807]
#   [0.80900025]
#   [0.80238384]
#   [0.79579431]
#   [0.78923655]
#   [0.78271437]
#   [0.77623111]
#   [0.76978952]
#   [0.76339227]]]
# ****************************************
# *index 23: current_pred : [0.7570414]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32), array([0.84882367], dtype=float32), array([0.842231], dtype=float32), array([0.83559954], dtype=float32), array([0.8289478], dtype=float32), array([0.8222903], dtype=float32), array([0.81563807], dtype=float32), array([0.80900025], dtype=float32), array([0.80238384], dtype=float32), array([0.7957943], dtype=float32), array([0.78923655], dtype=float32), array([0.78271437], dtype=float32), array([0.7762311], dtype=float32), array([0.7697895], dtype=float32), array([0.76339227], dtype=float32), array([0.7570414], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.78065704]
#   [0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]
#   [0.86808151]
#   [0.86178648]
#   [0.85535294]
#   [0.84882367]
#   [0.84223098]
#   [0.83559954]
#   [0.82894778]
#   [0.8222903 ]
#   [0.81563807]
#   [0.80900025]
#   [0.80238384]
#   [0.79579431]
#   [0.78923655]
#   [0.78271437]
#   [0.77623111]
#   [0.76978952]
#   [0.76339227]
#   [0.75704139]]]
# ****************************************
# *index 24: current_pred : [0.750739]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32), array([0.84882367], dtype=float32), array([0.842231], dtype=float32), array([0.83559954], dtype=float32), array([0.8289478], dtype=float32), array([0.8222903], dtype=float32), array([0.81563807], dtype=float32), array([0.80900025], dtype=float32), array([0.80238384], dtype=float32), array([0.7957943], dtype=float32), array([0.78923655], dtype=float32), array([0.78271437], dtype=float32), array([0.7762311], dtype=float32), array([0.7697895], dtype=float32), array([0.76339227], dtype=float32), array([0.7570414], dtype=float32), array([0.750739], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.77996875]
#   [0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]
#   [0.86808151]
#   [0.86178648]
#   [0.85535294]
#   [0.84882367]
#   [0.84223098]
#   [0.83559954]
#   [0.82894778]
#   [0.8222903 ]
#   [0.81563807]
#   [0.80900025]
#   [0.80238384]
#   [0.79579431]
#   [0.78923655]
#   [0.78271437]
#   [0.77623111]
#   [0.76978952]
#   [0.76339227]
#   [0.75704139]
#   [0.75073898]]]
# ****************************************
# *index 25: current_pred : [0.74448675]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32), array([0.84882367], dtype=float32), array([0.842231], dtype=float32), array([0.83559954], dtype=float32), array([0.8289478], dtype=float32), array([0.8222903], dtype=float32), array([0.81563807], dtype=float32), array([0.80900025], dtype=float32), array([0.80238384], dtype=float32), array([0.7957943], dtype=float32), array([0.78923655], dtype=float32), array([0.78271437], dtype=float32), array([0.7762311], dtype=float32), array([0.7697895], dtype=float32), array([0.76339227], dtype=float32), array([0.7570414], dtype=float32), array([0.750739], dtype=float32), array([0.74448675], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.78119652]
#   [0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]
#   [0.86808151]
#   [0.86178648]
#   [0.85535294]
#   [0.84882367]
#   [0.84223098]
#   [0.83559954]
#   [0.82894778]
#   [0.8222903 ]
#   [0.81563807]
#   [0.80900025]
#   [0.80238384]
#   [0.79579431]
#   [0.78923655]
#   [0.78271437]
#   [0.77623111]
#   [0.76978952]
#   [0.76339227]
#   [0.75704139]
#   [0.75073898]
#   [0.74448675]]]
# ****************************************
# *index 26: current_pred : [0.73828626]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32), array([0.84882367], dtype=float32), array([0.842231], dtype=float32), array([0.83559954], dtype=float32), array([0.8289478], dtype=float32), array([0.8222903], dtype=float32), array([0.81563807], dtype=float32), array([0.80900025], dtype=float32), array([0.80238384], dtype=float32), array([0.7957943], dtype=float32), array([0.78923655], dtype=float32), array([0.78271437], dtype=float32), array([0.7762311], dtype=float32), array([0.7697895], dtype=float32), array([0.76339227], dtype=float32), array([0.7570414], dtype=float32), array([0.750739], dtype=float32), array([0.74448675], dtype=float32), array([0.73828626], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.7782015 ]
#   [0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]
#   [0.86808151]
#   [0.86178648]
#   [0.85535294]
#   [0.84882367]
#   [0.84223098]
#   [0.83559954]
#   [0.82894778]
#   [0.8222903 ]
#   [0.81563807]
#   [0.80900025]
#   [0.80238384]
#   [0.79579431]
#   [0.78923655]
#   [0.78271437]
#   [0.77623111]
#   [0.76978952]
#   [0.76339227]
#   [0.75704139]
#   [0.75073898]
#   [0.74448675]
#   [0.73828626]]]
# ****************************************
# *index 27: current_pred : [0.7321391]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32), array([0.84882367], dtype=float32), array([0.842231], dtype=float32), array([0.83559954], dtype=float32), array([0.8289478], dtype=float32), array([0.8222903], dtype=float32), array([0.81563807], dtype=float32), array([0.80900025], dtype=float32), array([0.80238384], dtype=float32), array([0.7957943], dtype=float32), array([0.78923655], dtype=float32), array([0.78271437], dtype=float32), array([0.7762311], dtype=float32), array([0.7697895], dtype=float32), array([0.76339227], dtype=float32), array([0.7570414], dtype=float32), array([0.750739], dtype=float32), array([0.74448675], dtype=float32), array([0.73828626], dtype=float32), array([0.7321391], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.73675497]
#   [0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]
#   [0.86808151]
#   [0.86178648]
#   [0.85535294]
#   [0.84882367]
#   [0.84223098]
#   [0.83559954]
#   [0.82894778]
#   [0.8222903 ]
#   [0.81563807]
#   [0.80900025]
#   [0.80238384]
#   [0.79579431]
#   [0.78923655]
#   [0.78271437]
#   [0.77623111]
#   [0.76978952]
#   [0.76339227]
#   [0.75704139]
#   [0.75073898]
#   [0.74448675]
#   [0.73828626]
#   [0.73213911]]]
# ****************************************
# *index 28: current_pred : [0.7260468]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32), array([0.84882367], dtype=float32), array([0.842231], dtype=float32), array([0.83559954], dtype=float32), array([0.8289478], dtype=float32), array([0.8222903], dtype=float32), array([0.81563807], dtype=float32), array([0.80900025], dtype=float32), array([0.80238384], dtype=float32), array([0.7957943], dtype=float32), array([0.78923655], dtype=float32), array([0.78271437], dtype=float32), array([0.7762311], dtype=float32), array([0.7697895], dtype=float32), array([0.76339227], dtype=float32), array([0.7570414], dtype=float32), array([0.750739], dtype=float32), array([0.74448675], dtype=float32), array([0.73828626], dtype=float32), array([0.7321391], dtype=float32), array([0.7260468], dtype=float32)]
# ---------------------------------
# current_batch :
#  [[[0.72899769]
#   [0.74382395]
#   [0.75132078]
#   [0.75591562]
#   [0.76843515]
#   [0.77561575]
#   [0.76430538]
#   [0.77937347]
#   [0.78201503]
#   [0.79792023]
#   [0.81851328]
#   [0.82688444]
#   [0.82308952]
#   [0.83080958]
#   [0.82519161]
#   [0.83854826]
#   [0.85238857]
#   [0.85802515]
#   [0.86081554]
#   [0.85860183]
#   [0.85556961]
#   [0.85415582]
#   [0.87045167]
#   [0.91820448]
#   [0.89658829]
#   [0.91072624]
#   [0.90791726]
#   [0.91729295]
#   [0.92019495]
#   [0.93548627]
#   [0.93381204]
#   [0.89842469]
#   [0.89462918]
#   [0.89038658]
#   [0.88545591]
#   [0.88000697]
#   [0.87418067]
#   [0.86808151]
#   [0.86178648]
#   [0.85535294]
#   [0.84882367]
#   [0.84223098]
#   [0.83559954]
#   [0.82894778]
#   [0.8222903 ]
#   [0.81563807]
#   [0.80900025]
#   [0.80238384]
#   [0.79579431]
#   [0.78923655]
#   [0.78271437]
#   [0.77623111]
#   [0.76978952]
#   [0.76339227]
#   [0.75704139]
#   [0.75073898]
#   [0.74448675]
#   [0.73828626]
#   [0.73213911]
#   [0.7260468 ]]]
# ****************************************
# *index 29: current_pred : [0.72001064]
# ----------------------
# *test_predictions :
# ...
#   [0.52822387]
#   [0.52491856]
#   [0.52167314]
#   [0.5184871 ]
#   [0.51535976]
#   [0.51229042]
#   [0.5092783 ]
#   [0.50632286]
#   [0.50342333]
#   [0.500579  ]
#   [0.49778908]
#   [0.49505302]
#   [0.49236995]
#   [0.48973912]
#   [0.48715982]
#   [0.48463136]
#   [0.48215297]
#   [0.47972384]
#   [0.47734326]
#   [0.47501051]
#   [0.47272491]
#   [0.47048557]
#   [0.46829185]
#   [0.46614295]
#   [0.46403822]
#   [0.46197686]
#   [0.45995817]
#   [0.45798147]
#   [0.45604596]
#   [0.45415092]
#   [0.45229545]
#   [0.45047909]
#   [0.4487015 ]
#   [0.44696209]
#   [0.44526041]
#   [0.44359577]
#   [0.44196752]
#   [0.44037506]
#   [0.43881768]
#   [0.43729481]
#   [0.43580562]
#   [0.43434966]
#   [0.43292609]
#   [0.43153444]
#   [0.43017393]
#   [0.42884398]
#   [0.427544  ]]]
# ****************************************
# *index 117: current_pred : [0.42627335]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32), array([0.84882367], dtype=float32), array([0.842231], dtype=float32), array([0.83559954], dtype=float32), array([0.8289478], dtype=float32), array([0.8222903], dtype=float32), array([0.81563807], dtype=float32), array([0.80900025], dtype=float32), array([0.80238384], dtype=float32), array([0.7957943], dtype=float32), array([0.78923655], dtype=float32), array([0.78271437], dtype=float32), array([0.7762311], dtype=float32), array([0.7697895], dtype=float32), array([0.76339227], dtype=float32), array([0.7570414], dtype=float32), array([0.750739], dtype=float32), array([0.74448675], dtype=float32), array([0.73828626], dtype=float32), array([0.7321391], dtype=float32), array([0.7260468], dtype=float32), array([0.72001064], dtype=float32), array([0.7140316], dtype=float32), array([0.70811105], dtype=float32), array([0.70224994], dtype=float32), array([0.69644946], dtype=float32), array([0.6907103], dtype=float32), array([0.6850336], dtype=float32), array([0.6794199], dtype=float32), array([0.67387], dtype=float32), array([0.6683848], dtype=float32), array([0.66296464], dtype=float32), array([0.6576102], dtype=float32), array([0.6523219], dtype=float32), array([0.6471003], dtype=float32), array([0.64194584], dtype=float32), array([0.63685876], dtype=float32), array([0.6318393], dtype=float32), array([0.62688774], dtype=float32), array([0.6220043], dtype=float32), array([0.617189], dtype=float32), array([0.612442], dtype=float32), array([0.6077633], dtype=float32), array([0.6031528], dtype=float32), array([0.5986107], dtype=float32), array([0.59413666], dtype=float32), array([0.5897306], dtype=float32), array([0.58539236], dtype=float32), array([0.5811217], dtype=float32), array([0.5769183], dtype=float32), array([0.5727819], dtype=float32), array([0.5687123], dtype=float32), array([0.564709], dtype=float32), array([0.5607715], dtype=float32), array([0.5568997], dtype=float32), array([0.55309284], dtype=float32), array([0.5493507], dtype=float32), array([0.5456725], dtype=float32), array([0.5420579], dtype=float32), array([0.5385063], dtype=float32), array([0.5350172], dtype=float32), array([0.5315899], dtype=float32), array([0.5282239], dtype=float32), array([0.52491856], dtype=float32), array([0.52167314], dtype=float32), array([0.5184871], dtype=float32), array([0.51535976], dtype=float32), array([0.5122904], dtype=float32), array([0.5092783], dtype=float32), array([0.50632286], dtype=float32), array([0.50342333], dtype=float32), array([0.500579], dtype=float32), array([0.49778908], dtype=float32), array([0.49505302], dtype=float32), array([0.49236995], dtype=float32), array([0.48973912], dtype=float32), array([0.48715982], dtype=float32), array([0.48463136], dtype=float32), array([0.48215297], dtype=float32), array([0.47972384], dtype=float32), array([0.47734326], dtype=float32), array([0.4750105], dtype=float32), array([0.4727249], dtype=float32), array([0.47048557], dtype=float32), array([0.46829185], dtype=float32), array([0.46614295], dtype=float32), array([0.46403822], dtype=float32), array([0.46197686], dtype=float32), array([0.45995817], dtype=float32), array([0.45798147], dtype=float32), array([0.45604596], dtype=float32), array([0.45415092], dtype=float32), array([0.45229545], dtype=float32), array([0.4504791], dtype=float32), array([0.4487015], dtype=float32), array([0.4469621], dtype=float32), array([0.4452604], dtype=float32), array([0.44359577], dtype=float32), array([0.44196752], dtype=float32), array([0.44037506], dtype=float32), array([0.43881768], dtype=float32), array([0.4372948], dtype=float32), array([0.43580562], dtype=float32), array([0.43434966], dtype=float32), array([0.4329261], dtype=float32) ...
# ---------------------------------
# current_batch :
#  [[[0.57278192]
#   [0.56871229]
#   [0.56470901]
#   [0.56077152]
#   [0.55689973]
#   [0.55309284]
#   [0.54935068]
#   [0.54567248]
#   [0.54205787]
#   [0.53850633]
#   [0.53501719]
#   [0.53158993]
#   [0.52822387]
#   [0.52491856]
#   [0.52167314]
#   [0.5184871 ]
#   [0.51535976]
#   [0.51229042]
#   [0.5092783 ]
#   [0.50632286]
#   [0.50342333]
#   [0.500579  ]
#   [0.49778908]
#   [0.49505302]
#   [0.49236995]
#   [0.48973912]
#   [0.48715982]
#   [0.48463136]
#   [0.48215297]
#   [0.47972384]
#   [0.47734326]
#   [0.47501051]
#   [0.47272491]
#   [0.47048557]
#   [0.46829185]
#   [0.46614295]
#   [0.46403822]
#   [0.46197686]
#   [0.45995817]
#   [0.45798147]
#   [0.45604596]
#   [0.45415092]
#   [0.45229545]
#   [0.45047909]
#   [0.4487015 ]
#   [0.44696209]
#   [0.44526041]
#   [0.44359577]
#   [0.44196752]
#   [0.44037506]
#   [0.43881768]
#   [0.43729481]
#   [0.43580562]
#   [0.43434966]
#   [0.43292609]
#   [0.43153444]
#   [0.43017393]
#   [0.42884398]
#   [0.427544  ]
#   [0.42627335]]]
# ****************************************
# *index 118: current_pred : [0.42503145]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32), array([0.84882367], dtype=float32), array([0.842231], dtype=float32), array([0.83559954], dtype=float32), array([0.8289478], dtype=float32), array([0.8222903], dtype=float32), array([0.81563807], dtype=float32), array([0.80900025], dtype=float32), array([0.80238384], dtype=float32), array([0.7957943], dtype=float32), array([0.78923655], dtype=float32), array([0.78271437], dtype=float32), array([0.7762311], dtype=float32), array([0.7697895], dtype=float32), array([0.76339227], dtype=float32), array([0.7570414], dtype=float32), array([0.750739], dtype=float32), array([0.74448675], dtype=float32), array([0.73828626], dtype=float32), array([0.7321391], dtype=float32), array([0.7260468], dtype=float32), array([0.72001064], dtype=float32), array([0.7140316], dtype=float32), array([0.70811105], dtype=float32), array([0.70224994], dtype=float32), array([0.69644946], dtype=float32), array([0.6907103], dtype=float32), array([0.6850336], dtype=float32), array([0.6794199], dtype=float32), array([0.67387], dtype=float32), array([0.6683848], dtype=float32), array([0.66296464], dtype=float32), array([0.6576102], dtype=float32), array([0.6523219], dtype=float32), array([0.6471003], dtype=float32), array([0.64194584], dtype=float32), array([0.63685876], dtype=float32), array([0.6318393], dtype=float32), array([0.62688774], dtype=float32), array([0.6220043], dtype=float32), array([0.617189], dtype=float32), array([0.612442], dtype=float32), array([0.6077633], dtype=float32), array([0.6031528], dtype=float32), array([0.5986107], dtype=float32), array([0.59413666], dtype=float32), array([0.5897306], dtype=float32), array([0.58539236], dtype=float32), array([0.5811217], dtype=float32), array([0.5769183], dtype=float32), array([0.5727819], dtype=float32), array([0.5687123], dtype=float32), array([0.564709], dtype=float32), array([0.5607715], dtype=float32), array([0.5568997], dtype=float32), array([0.55309284], dtype=float32), array([0.5493507], dtype=float32), array([0.5456725], dtype=float32), array([0.5420579], dtype=float32), array([0.5385063], dtype=float32), array([0.5350172], dtype=float32), array([0.5315899], dtype=float32), array([0.5282239], dtype=float32), array([0.52491856], dtype=float32), array([0.52167314], dtype=float32), array([0.5184871], dtype=float32), array([0.51535976], dtype=float32), array([0.5122904], dtype=float32), array([0.5092783], dtype=float32), array([0.50632286], dtype=float32), array([0.50342333], dtype=float32), array([0.500579], dtype=float32), array([0.49778908], dtype=float32), array([0.49505302], dtype=float32), array([0.49236995], dtype=float32), array([0.48973912], dtype=float32), array([0.48715982], dtype=float32), array([0.48463136], dtype=float32), array([0.48215297], dtype=float32), array([0.47972384], dtype=float32), array([0.47734326], dtype=float32), array([0.4750105], dtype=float32), array([0.4727249], dtype=float32), array([0.47048557], dtype=float32), array([0.46829185], dtype=float32), array([0.46614295], dtype=float32), array([0.46403822], dtype=float32), array([0.46197686], dtype=float32), array([0.45995817], dtype=float32), array([0.45798147], dtype=float32), array([0.45604596], dtype=float32), array([0.45415092], dtype=float32), array([0.45229545], dtype=float32), array([0.4504791], dtype=float32), array([0.4487015], dtype=float32), array([0.4469621], dtype=float32), array([0.4452604], dtype=float32), array([0.44359577], dtype=float32), array([0.44196752], dtype=float32), array([0.44037506], dtype=float32), array([0.43881768], dtype=float32), array([0.4372948], dtype=float32), array([0.43580562], dtype=float32), array([0.43434966], dtype=float32), array([0.4329261], dtype=float32) ...
# ---------------------------------
# current_batch :
#  [[[0.56871229]
#   [0.56470901]
#   [0.56077152]
#   [0.55689973]
#   [0.55309284]
#   [0.54935068]
#   [0.54567248]
#   [0.54205787]
#   [0.53850633]
#   [0.53501719]
#   [0.53158993]
#   [0.52822387]
#   [0.52491856]
#   [0.52167314]
#   [0.5184871 ]
#   [0.51535976]
#   [0.51229042]
#   [0.5092783 ]
#   [0.50632286]
#   [0.50342333]
#   [0.500579  ]
#   [0.49778908]
#   [0.49505302]
#   [0.49236995]
#   [0.48973912]
#   [0.48715982]
#   [0.48463136]
#   [0.48215297]
#   [0.47972384]
#   [0.47734326]
#   [0.47501051]
#   [0.47272491]
#   [0.47048557]
#   [0.46829185]
#   [0.46614295]
#   [0.46403822]
#   [0.46197686]
#   [0.45995817]
#   [0.45798147]
#   [0.45604596]
#   [0.45415092]
#   [0.45229545]
#   [0.45047909]
#   [0.4487015 ]
#   [0.44696209]
#   [0.44526041]
#   [0.44359577]
#   [0.44196752]
#   [0.44037506]
#   [0.43881768]
#   [0.43729481]
#   [0.43580562]
#   [0.43434966]
#   [0.43292609]
#   [0.43153444]
#   [0.43017393]
#   [0.42884398]
#   [0.427544  ]
#   [0.42627335]
#   [0.42503145]]]
# ****************************************
# *index 119: current_pred : [0.42381766]
# ----------------------
# *test_predictions :
#  [array([0.8984247], dtype=float32), array([0.8946292], dtype=float32), array([0.8903866], dtype=float32), array([0.8854559], dtype=float32), array([0.88000697], dtype=float32), array([0.8741807], dtype=float32), array([0.8680815], dtype=float32), array([0.8617865], dtype=float32), array([0.85535294], dtype=float32), array([0.84882367], dtype=float32), array([0.842231], dtype=float32), array([0.83559954], dtype=float32), array([0.8289478], dtype=float32), array([0.8222903], dtype=float32), array([0.81563807], dtype=float32), array([0.80900025], dtype=float32), array([0.80238384], dtype=float32), array([0.7957943], dtype=float32), array([0.78923655], dtype=float32), array([0.78271437], dtype=float32), array([0.7762311], dtype=float32), array([0.7697895], dtype=float32), array([0.76339227], dtype=float32), array([0.7570414], dtype=float32), array([0.750739], dtype=float32), array([0.74448675], dtype=float32), array([0.73828626], dtype=float32), array([0.7321391], dtype=float32), array([0.7260468], dtype=float32), array([0.72001064], dtype=float32), array([0.7140316], dtype=float32), array([0.70811105], dtype=float32), array([0.70224994], dtype=float32), array([0.69644946], dtype=float32), array([0.6907103], dtype=float32), array([0.6850336], dtype=float32), array([0.6794199], dtype=float32), array([0.67387], dtype=float32), array([0.6683848], dtype=float32), array([0.66296464], dtype=float32), array([0.6576102], dtype=float32), array([0.6523219], dtype=float32), array([0.6471003], dtype=float32), array([0.64194584], dtype=float32), array([0.63685876], dtype=float32), array([0.6318393], dtype=float32), array([0.62688774], dtype=float32), array([0.6220043], dtype=float32), array([0.617189], dtype=float32), array([0.612442], dtype=float32), array([0.6077633], dtype=float32), array([0.6031528], dtype=float32), array([0.5986107], dtype=float32), array([0.59413666], dtype=float32), array([0.5897306], dtype=float32), array([0.58539236], dtype=float32), array([0.5811217], dtype=float32), array([0.5769183], dtype=float32), array([0.5727819], dtype=float32), array([0.5687123], dtype=float32), array([0.564709], dtype=float32), array([0.5607715], dtype=float32), array([0.5568997], dtype=float32), array([0.55309284], dtype=float32), array([0.5493507], dtype=float32), array([0.5456725], dtype=float32), array([0.5420579], dtype=float32), array([0.5385063], dtype=float32), array([0.5350172], dtype=float32), array([0.5315899], dtype=float32), array([0.5282239], dtype=float32), array([0.52491856], dtype=float32), array([0.52167314], dtype=float32), array([0.5184871], dtype=float32), array([0.51535976], dtype=float32), array([0.5122904], dtype=float32), array([0.5092783], dtype=float32), array([0.50632286], dtype=float32), array([0.50342333], dtype=float32), array([0.500579], dtype=float32), array([0.49778908], dtype=float32), array([0.49505302], dtype=float32), array([0.49236995], dtype=float32), array([0.48973912], dtype=float32), array([0.48715982], dtype=float32), array([0.48463136], dtype=float32), array([0.48215297], dtype=float32), array([0.47972384], dtype=float32), array([0.47734326], dtype=float32), array([0.4750105], dtype=float32), array([0.4727249], dtype=float32), array([0.47048557], dtype=float32), array([0.46829185], dtype=float32), array([0.46614295], dtype=float32), array([0.46403822], dtype=float32), array([0.46197686], dtype=float32), array([0.45995817], dtype=float32), array([0.45798147], dtype=float32), array([0.45604596], dtype=float32), array([0.45415092], dtype=float32), array([0.45229545], dtype=float32), array([0.4504791], dtype=float32), array([0.4487015], dtype=float32), array([0.4469621], dtype=float32), array([0.4452604], dtype=float32), array([0.44359577], dtype=float32), array([0.44196752], dtype=float32), array([0.44037506], dtype=float32), array([0.43881768], dtype=float32), array([0.4372948], dtype=float32), array([0.43580562], dtype=float32), array([0.43434966], dtype=float32), array([0.4329261], dtype=float32) ...
# ---------------------------------
# current_batch :
#  [[[0.56470901]
#   [0.56077152]
#   [0.55689973]
#   [0.55309284]
#   [0.54935068]
#   [0.54567248]
#   [0.54205787]
#   [0.53850633]
#   [0.53501719]
#   [0.53158993]
#   [0.52822387]
#   [0.52491856]
#   [0.52167314]
#   [0.5184871 ]
#   [0.51535976]
#   [0.51229042]
#   [0.5092783 ]
#   [0.50632286]
#   [0.50342333]
#   [0.500579  ]
#   [0.49778908]
#   [0.49505302]
#   [0.49236995]
#   [0.48973912]
#   [0.48715982]
#   [0.48463136]
#   [0.48215297]
#   [0.47972384]
#   [0.47734326]
#   [0.47501051]
#   [0.47272491]
#   [0.47048557]
#   [0.46829185]
#   [0.46614295]
#   [0.46403822]
#   [0.46197686]
#   [0.45995817]
#   [0.45798147]
#   [0.45604596]
#   [0.45415092]
#   [0.45229545]
#   [0.45047909]
#   [0.4487015 ]
#   [0.44696209]
#   [0.44526041]
#   [0.44359577]
#   [0.44196752]
#   [0.44037506]
#   [0.43881768]
#   [0.43729481]
#   [0.43580562]
#   [0.43434966]
#   [0.43292609]
#   [0.43153444]
#   [0.43017393]
#   [0.42884398]
#   [0.427544  ]
#   [0.42627335]
#   [0.42503145]
#   [0.42381766]]]
# ****************************************

# %% [markdown]
# ## Inverse Transformations and Compare

# %%
print( len(test_predictions) ) 
print( test_predictions[0].shape)
test_predictions # 1 list consists of 80 np.array
# Out:
# 120
# (1,)
# [array([0.8984247], dtype=float32),
#  array([0.8946292], dtype=float32),
#  array([0.8903866], dtype=float32),
#  array([0.8854559], dtype=float32),
#  array([0.88000697], dtype=float32),
#  array([0.8741807], dtype=float32),
#  array([0.8680815], dtype=float32),
#  array([0.8617865], dtype=float32),
#  array([0.85535294], dtype=float32),
#  array([0.84882367], dtype=float32),
#  array([0.842231], dtype=float32),
#  array([0.83559954], dtype=float32),
#  array([0.8289478], dtype=float32),
#  array([0.8222903], dtype=float32),
#  array([0.81563807], dtype=float32),
#  array([0.80900025], dtype=float32),
#  array([0.80238384], dtype=float32),
#  array([0.7957943], dtype=float32),
#  array([0.78923655], dtype=float32),
#  array([0.78271437], dtype=float32),
#  array([0.7762311], dtype=float32),
#  array([0.7697895], dtype=float32),
#  array([0.76339227], dtype=float32),
#  array([0.7570414], dtype=float32),
#  array([0.750739], dtype=float32),
#  array([0.74448675], dtype=float32),
#  array([0.73828626], dtype=float32),
#  array([0.7321391], dtype=float32),
#  array([0.7260468], dtype=float32),
#  array([0.72001064], dtype=float32),
#  array([0.7140316], dtype=float32),
#  array([0.70811105], dtype=float32),
#  array([0.70224994], dtype=float32),
#  array([0.69644946], dtype=float32),
#  array([0.6907103], dtype=float32),
#  array([0.6850336], dtype=float32),
#  array([0.6794199], dtype=float32),
#  array([0.67387], dtype=float32),
#  array([0.6683848], dtype=float32),
#  array([0.66296464], dtype=float32),
#  array([0.6576102], dtype=float32),
#  array([0.6523219], dtype=float32),
#  array([0.6471003], dtype=float32),
#  array([0.64194584], dtype=float32),
#  array([0.63685876], dtype=float32),
#  array([0.6318393], dtype=float32),
#  array([0.62688774], dtype=float32),
#  array([0.6220043], dtype=float32),
#  array([0.617189], dtype=float32),
#  array([0.612442], dtype=float32),
#  array([0.6077633], dtype=float32),
#  array([0.6031528], dtype=float32),
#  array([0.5986107], dtype=float32),
#  array([0.59413666], dtype=float32),
#  array([0.5897306], dtype=float32),
#  array([0.58539236], dtype=float32),
#  array([0.5811217], dtype=float32),
#  array([0.5769183], dtype=float32),
#  array([0.5727819], dtype=float32),
#  array([0.5687123], dtype=float32),
#  array([0.564709], dtype=float32),
#  array([0.5607715], dtype=float32),
#  array([0.5568997], dtype=float32),
#  array([0.55309284], dtype=float32),
#  array([0.5493507], dtype=float32),
#  array([0.5456725], dtype=float32),
#  array([0.5420579], dtype=float32),
#  array([0.5385063], dtype=float32),
#  array([0.5350172], dtype=float32),
#  array([0.5315899], dtype=float32),
#  array([0.5282239], dtype=float32),
#  array([0.52491856], dtype=float32),
#  array([0.52167314], dtype=float32),
#  array([0.5184871], dtype=float32),
#  array([0.51535976], dtype=float32),
#  array([0.5122904], dtype=float32),
#  array([0.5092783], dtype=float32),
#  array([0.50632286], dtype=float32),
#  array([0.50342333], dtype=float32),
#  array([0.500579], dtype=float32),
#  array([0.49778908], dtype=float32),
#  array([0.49505302], dtype=float32),
#  array([0.49236995], dtype=float32),
#  array([0.48973912], dtype=float32),
#  array([0.48715982], dtype=float32),
#  array([0.48463136], dtype=float32),
#  array([0.48215297], dtype=float32),
#  array([0.47972384], dtype=float32),
#  array([0.47734326], dtype=float32),
#  array([0.4750105], dtype=float32),
#  array([0.4727249], dtype=float32),
#  array([0.47048557], dtype=float32),
#  array([0.46829185], dtype=float32),
#  array([0.46614295], dtype=float32),
#  array([0.46403822], dtype=float32),
#  array([0.46197686], dtype=float32),
#  array([0.45995817], dtype=float32),
#  array([0.45798147], dtype=float32),
#  array([0.45604596], dtype=float32),
#  array([0.45415092], dtype=float32),
#  array([0.45229545], dtype=float32),
#  array([0.4504791], dtype=float32),
#  array([0.4487015], dtype=float32),
#  array([0.4469621], dtype=float32),
#  array([0.4452604], dtype=float32),
#  array([0.44359577], dtype=float32),
#  array([0.44196752], dtype=float32),
#  array([0.44037506], dtype=float32),
#  array([0.43881768], dtype=float32),
#  array([0.4372948], dtype=float32),
#  array([0.43580562], dtype=float32),
#  array([0.43434966], dtype=float32),
#  array([0.4329261], dtype=float32),
#  array([0.43153444], dtype=float32),
#  array([0.43017393], dtype=float32),
#  array([0.42884398], dtype=float32),
#  array([0.427544], dtype=float32),
#  array([0.42627335], dtype=float32),
#  array([0.42503145], dtype=float32),
#  array([0.42381766], dtype=float32)]

# %%
true_predictions = scaler.inverse_transform(test_predictions) # scaled value -> actual value 
print(true_predictions.shape)
true_predictions #1 np array, it's shape is (80,1)
# Out:
# (120, 1)
# array([[762.07717367],
#        [760.03686223],
#        [757.75621071],
#        [755.10567704],
#        [752.17654624],
#        [749.04456341],
#        [745.76589655],
#        [742.38194273],
#        [738.92352545],
#        [735.4136502 ],
#        [731.86968326],
#        [728.30488962],
#        [724.72916997],
#        [721.15037438],
#        [717.5743984 ],
#        [714.00617637],
#        [710.44945708],
#        [706.90718831],
#        [703.38199743],
#        [699.87593508],
#        [696.39079554],
#        [692.92805272],
#        [689.48914845],
#        [686.07517214],
#        [682.68724522],
#        [679.32629689],
#        [675.9931602 ],
#        [672.68870028],
#        [669.41371814],
#        [666.16891869],
#        [662.95481459],
#        [659.77217483],
#        [656.62148001],
#        [653.50337096],
#        [650.41823218],
#        [647.36667245],
#        [644.34894808],
#        [641.36557175],
#        [638.41692794],
#        [635.50327298],
#        [632.62492728],
#        [629.78214718],
#        [626.97525307],
#        [624.20440517],
#        [621.46979573],
#        [618.77152086],
#        [616.10977282],
#        [613.48461568],
#        [610.89611353],
#        [608.34433044],
#        [605.82923439],
#        [603.35082536],
#        [600.90916745],
#        [598.50410044],
#        [596.13559229],
#        [593.80351485],
#        [591.50777198],
#        [589.24820348],
#        [587.02464915],
#        [584.83698082],
#        [582.6849742 ],
#        [580.56834093],
#        [578.48701692],
#        [576.44058564],
#        [574.42895096],
#        [572.45169636],
#        [570.50862957],
#        [568.59946225],
#        [566.72384193],
#        [564.88148024],
#        [563.07202473],
#        [561.29521908],
#        [559.5506147 ],
#        [557.83792324],
#        [556.15679223],
#        [554.50683718],
#        [552.88764156],
#        [551.29891701],
#        [549.74024698],
#        [548.21124698],
#        [546.71150048],
#        [545.2407031 ],
#        [543.79839022],
#        [542.38416135],
#        [540.99763198],
#        [539.63843365],
#        [538.30614982],
#        [537.00034794],
#        [535.72064351],
#        [534.46665205],
#        [533.23800507],
#        [532.03422196],
#        [530.85496629],
#        [529.69980551],
#        [528.56838717],
#        [527.46027871],
#        [526.37511165],
#        [525.31251753],
#        [524.2720638 ],
#        [523.25336595],
#        [522.25594337],
#        [521.27953974],
#        [520.32397882],
#        [519.38894021],
#        [518.4741836 ],
#        [517.57934052],
#        [516.70405851],
#        [515.84801717],
#        [515.010832  ],
#        [514.19219861],
#        [513.39166842],
#        [512.60900114],
#        [511.84374817],
#        [511.0956532 ],
#        [510.3642997 ],
#        [509.64936724],
#        [508.95055144],
#        [508.26749985],
#        [507.59990807],
#        [506.94742367]])

# %%
# IGNORE WARNINGS
test_split['Predictions'] = true_predictions
# Out:
# /home/ys/anaconda3/envs/tfg/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test_split
# Out:
#              Price  Predictions
# Date
# 2016-08-10  783.75   762.077174
# 2016-08-11  785.00   760.036862
# 2016-08-12  781.50   757.756211
# 2016-08-15  783.75   755.105677
# 2016-08-16  780.30   752.176546
# ...            ...          ...
# 2017-01-25  829.62   509.649367
# 2017-01-26  837.81   508.950551
# 2017-01-27  834.71   508.267500
# 2017-01-30  814.66   507.599908
# 2017-01-31  796.86   506.947424
#
# [120 rows x 2 columns]

# %%
test_split.plot(figsize=(12,8))

# %%
#############################original soulution from lecture #####################

# %%
#index slice dataFrame : all row, column index 1=='open'(instead 1 -> 1:2) 
training_set = df.iloc[:, 1:2].values

# %%
print(dataset_train.shape)
dataset_train.head()

# %%
print(training_set.shape)
training_set #numpy.ndarray

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
# sc = MinMaxScaler(feature_range = (0, 1))
sc = MinMaxScaler()

training_set_scaled = sc.fit_transform(training_set)

# %%
 1257-60

# %%
 1257-1197

# %%
print(training_set_scaled.shape)
training_set_scaled # 2-d np.array

# %%
print(training_set_scaled[:,0].shape)
training_set_scaled[:,0] #make 1-d np.array with 60 elements

# %%
# Test 
# Creating a data structure('open' price) with 60 timesteps and 1 output
X_train1 = []
y_train1 = []
for i in range(60, 65): #from 60 to 65-1 
    print("* i : ", i)
    X_train1.append(training_set_scaled[i-60:i, 0])#if i == 60, [0:60, 0], 61 [1:61, 0], 62 [2:62, 0],,, 64 [4:64, 0]
    print(f"*training_set_scaled[{i-60}:{i}, 0] \n")
    print(training_set_scaled[i-60:i, 0])
    
    print(f"*X_train1.append(training_set_scaled[{i-60}:{i}, 0])")
    print("* X_train1 - number of appended list : ",len(X_train1)) #list
  
    print("----------------------------------------------------\n")
    y_train1.append(training_set_scaled[i, 0]) #[60,0], [61,0], [62,0],,,[64,0]
    print(f"**training_set_scaled[{i}, 0]")
    print(training_set_scaled[i, 0])
    
    print(f"**y_train1.append(training_set_scaled[{i}, 0]) ")
    print("** y_train1 - number of appended list : ",len(y_train1)) #list
    
    print("================================================================")
X_train1, y_train1 = np.array(X_train1), np.array(y_train1)

# %%
print(X_train1.shape) #np.array
X_train1

# %%
print(y_train1.shape) #np.array
y_train1

# %%
# Creating a data structure('open' price) with 60 timesteps and 1 output
X_train = []
y_train = []
for i in range(60, 1258): #from 60 to 1258-1 
    X_train.append(training_set_scaled[i-60:i, 0])#if i == 60, [0:60, 0], 61 [1:61, 0], 62 [2:62, 0],,, 1257 [1197:1257, 0]
    y_train.append(training_set_scaled[i, 0]) #[60,0], [61,0], [62,0],,,[1257,0]
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
print(X_train.shape) 
X_train # scaled 'open' price with 60 time stamp

# %%
print(y_train.shape)
y_train

# %%
# Reshaping:(1198, 60) -> (1198, 60, 1)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1)) #(1198,60,1)

# %%
# Part 2 - Building the RNN

# Importing the Keras libraries and packages
from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense
# from tensorflow.keras.layers import LSTM
# from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense, LSTM, Dropout

# %%
# Initialising the RNN
regressor = Sequential()

# %%
# Adding the first LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1))) # 60,1
regressor.add(Dropout(0.2))

# %%
# Adding a second LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# %%
# Adding a third LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# %%
# Adding a fourth LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

# %%
# Adding the output layer
regressor.add(Dense(units = 1))

# %%
# Compiling the RNN
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
# Fitting the RNN to the Training set
regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)

# %%
# Part 3 - Making the predictions and visualising the results using Test csv file.(20, 6)

# Getting the real stock price of 2017

# dataset_test = pd.read_csv('Google_Stock_Price_Test.csv')
dataset_test = pd.read_csv('Google_Stock_Price_Test.csv')
print(dataset_test.shape)
dataset_test.head()

# %%
real_stock_price = dataset_test.iloc[:, 1:2].values
print(real_stock_price.shape)
real_stock_price

# %%
dataset_train['Open'] #1258

# %%
dataset_test['Open'] #20

# %%
# Getting the predicted stock price of 2017
dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), axis = 0) #1258 + 20 => 1278
print(dataset_total.shape)
dataset_total #1278

# %%
print(len(dataset_total))
print(len(dataset_test))
1278 - 20 - 60

# %%
#[1278 - 20 - 60] =>  dataset_total[1198:].values
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
print(inputs.shape) #1-d
print(len(inputs))
inputs #dataset_total[1198:].values #80

# %%
inputs = inputs.reshape(-1,1)
print(inputs.shape) #2-d
print(inputs)
print("-----------------")
inputs = sc.transform(inputs)
print(inputs.shape)
inputs

# %%
X_test = []
for i in range(60, 80):
    print(f"* inputs[{i-60}:{i}, 0] \n")
    print(inputs[i-60:i, 0])
    X_test.append(inputs[i-60:i, 0])
    print(f"** X_test.append(inputs[{i-60}:{i}, 0]) \n")
    print("--------------------------------------------------------------")

# %%
X_test = np.array(X_test)
print(X_test.shape) #(20, 60)
print(X_test)
print("----------------------------------------------------")

X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape) #(20, 60, 1)
print(X_test)

# %%
predicted_stock_price = regressor.predict(X_test)#(20, 60, 1) -> (20, 1)
print(predicted_stock_price.shape)
predicted_stock_price

# %%
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
print(predicted_stock_price.shape)
predicted_stock_price

# %% [markdown]
# ### reference:  LSTM model
# ```
# test_size = 24
# length  = 18
# n_features = 1
# train = df[:-test_size]
# test = df[-test_size:]
# scaler = MinMaxScaler()
# scaler.fit(train)
# scaled_train = scaler.transform(train)
# scaled_test = scaler.transform(test)
#
# ```
#
# ```
# generator = TimeseriesGenerator(scaled_train, scaled_train, length=length, batch_size=batch_size)
# ```
# ```
# model = Sequential()
# model.add(LSTM(100,input_shape=(length, n_features)))
# model.add(Dense(1))
# model.compile(optimizer='adam', loss='mse')
# ```
#
# ```
# early_stop = EarlyStopping(monitor='val_loss',patience=3)
# validation_generator = TimeseriesGenerator(scaled_test,scaled_test, length=length, batch_size=1)
# model.fit_generator(generator, epochs = 20,
#                    validation_data=validation_generator,
#                    callbacks=[early_stop])
# ```
#
# ```
# test_predictions =[]
# current_batch = scaled_train[-length:].reshape(1,length,n_features)
#
# for i in range(len(test)):
#     current_pred = model.predict(current_batch)[0]
#     test_predictions.append(current_pred)
#     current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
#
# ```
#
# ```
# true_predictions = scaler.inverse_transform(test_predictions)
# ```

# %%
# Visualising the results

#dataset_test -> real_stock_price -> (20, 1)
plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price') 
## predicted_stock_price = regressor.predict(X_test)#(20, 60, 1) -> (20, 1)
#predicted_stock_price -> (20, 1)
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
